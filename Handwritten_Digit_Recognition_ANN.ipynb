# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
import tkinter as tk
from PIL import Image, ImageDraw
from scipy.ndimage import center_of_mass, shift

# %% [markdown]
# # Load MNIST Dataset

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# # Normalize the Data

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # Convert Labels to Categorical

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# # Build ANN Model

# %%
model = Sequential()

model.add(Flatten(input_shape=(28, 28)))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(64, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Compile the Model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Add Noise

# %%
X_train = X_train + np.random.normal(0, 0.05, X_train.shape)
X_train = np.clip(X_train, 0, 1)

# %% [markdown]
# # Train the Model

# %%
model.fit(
    X_train,
    y_train,
    epochs=25,
    batch_size=128,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7664 - loss: 0.7391 - val_accuracy: 0.9538 - val_loss: 0.1440
# Epoch 2/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9436 - loss: 0.1886 - val_accuracy: 0.9651 - val_loss: 0.1139
# Epoch 3/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9568 - loss: 0.1372 - val_accuracy: 0.9718 - val_loss: 0.0913
# Epoch 4/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9669 - loss: 0.1087 - val_accuracy: 0.9743 - val_loss: 0.0905
# Epoch 5/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9721 - loss: 0.0899 - val_accuracy: 0.9738 - val_loss: 0.0909
# Epoch 6/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9757 - loss: 0.0803 - val_accuracy: 0.9764 - val_loss: 0.0771
# Epoch 7/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9787 - loss: 0.0663 - val_accuracy: 0.9758 - val_loss: 0.0838
# Epoch 8/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9801 - loss: 0.0633 - val_accuracy: 0.9783 - val_loss: 0.0805
# Epoch 9/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9831 - loss: 0.0555 - val_accuracy: 0.9793 - val_loss: 0.0783
# Epoch 10/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9821 - loss: 0.0535 - val_accuracy: 0.9796 - val_loss: 0.0775
# Epoch 11/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9829 - loss: 0.0520 - val_accuracy: 0.9781 - val_loss: 0.0817
# Epoch 12/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9848 - loss: 0.0464 - val_accuracy: 0.9785 - val_loss: 0.0816
# Epoch 13/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9842 - loss: 0.0491 - val_accuracy: 0.9780 - val_loss: 0.0821
# Epoch 14/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9864 - loss: 0.0404 - val_accuracy: 0.9807 - val_loss: 0.0765
# Epoch 15/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9868 - loss: 0.0394 - val_accuracy: 0.9830 - val_loss: 0.0770
# Epoch 16/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9884 - loss: 0.0362 - val_accuracy: 0.9823 - val_loss: 0.0745
# Epoch 17/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9885 - loss: 0.0361 - val_accuracy: 0.9783 - val_loss: 0.0862
# Epoch 18/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9897 - loss: 0.0321 - val_accuracy: 0.9826 - val_loss: 0.0707
# Epoch 19/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9893 - loss: 0.0321 - val_accuracy: 0.9820 - val_loss: 0.0785
# Epoch 20/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9898 - loss: 0.0316 - val_accuracy: 0.9809 - val_loss: 0.0850
# Epoch 21/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9902 - loss: 0.0295 - val_accuracy: 0.9806 - val_loss: 0.0841
# Epoch 22/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9904 - loss: 0.0299 - val_accuracy: 0.9816 - val_loss: 0.0843
# Epoch 23/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9896 - loss: 0.0323 - val_accuracy: 0.9786 - val_loss: 0.0984
# Epoch 24/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9899 - loss: 0.0321 - val_accuracy: 0.9825 - val_loss: 0.0847
# Epoch 25/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9917 - loss: 0.0261 - val_accuracy: 0.9807 - val_loss: 0.0880

# %% [markdown]
# # Evaluate the Model

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9796 - loss: 0.0896
# Test Accuracy: 0.9842000007629395

# %% [markdown]
# # Drawing Canvas Code

# %%
# Create canvas
canvas_width = 280
canvas_height = 280

window = tk.Tk()
window.title("Draw a Digit")

canvas = tk.Canvas(window, width=canvas_width, height=canvas_height, bg='white')
canvas.pack()

image = Image.new("L", (canvas_width, canvas_height), 255)
draw = ImageDraw.Draw(image)

# Drawing Function
def paint(event):
    x1, y1 = event.x - 12, event.y - 12
    x2, y2 = event.x + 12, event.y + 12
    canvas.create_oval(x1, y1, x2, y2, fill='black')
    draw.ellipse([x1, y1, x2, y2], fill=0)

canvas.bind("<B1-Motion>", paint)

# SINGLE predict function
def predict_digit():
    img = image.resize((28, 28))
    img = np.array(img)

    img = 255 - img
    img = img / 255.0
    img[img < 0.2] = 0

    cy, cx = center_of_mass(img)
    img = shift(img, shift=[14 - cy, 14 - cx])

    img = img.reshape(1, 28, 28)

    prediction = model.predict(img)
    digit = np.argmax(prediction)

    result_label.config(text=f"Predicted Digit: {digit}")

# clear canvas 
def clear_canvas():
    canvas.delete("all")
    draw.rectangle([0, 0, canvas_width, canvas_height], fill=255)
    result_label.config(text="Draw a Digit")

# Buttons & Label
predict_button = tk.Button(window, text="Predict", command=predict_digit)
predict_button.pack()

clear_button = tk.Button(window, text="Clear", command=clear_canvas)
clear_button.pack()

result_label = tk.Label(window, text="Draw a Digit", font=("Arial", 16))
result_label.pack()

# Run Application
window.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
